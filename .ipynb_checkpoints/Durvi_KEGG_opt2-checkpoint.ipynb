# %%
##============================================
## Importing important libraries 
##============================================

import pandas as pd
import requests
import io
import itertools
import matplotlib.pyplot as plt
from venn import venn
from itertools import combinations

# %%
##==========================================
## Fetching data from KEGG 
##==========================================

def load_kegg_data(url):
    """
    Fetching KEGG REST data and load it as a Dataframe
    """
    print(f"Fetching data from {url}...")
    response = requests.get(url)
    if response.status_code == 200:
        return pd.read_csv(io.StringIO(response.text), sep='\t', header=None)
    else:
        raise Exception(f"Failed to fetch data from {url}")

# Load Pathways
pathway = load_kegg_data("https://rest.kegg.jp/list/pathway/hsa")
pathway.columns = ['PATHWAY_ID', 'PATHWAY_NAME']

# Load Gene-Pathway Link
gene_pathway = load_kegg_data("https://rest.kegg.jp/link/pathway/hsa")
gene_pathway.columns = ['GENE_ID', 'PATHWAY_ID']
# Removing 'path:' prefix so it matches pathway list
gene_pathway["PATHWAY_ID"] = gene_pathway["PATHWAY_ID"].str.replace("path:", "", regex=False)


# Load Gene Info 
gene_info = load_kegg_data("https://rest.kegg.jp/list/hsa")
gene_info.columns = ['GENE_ID', 'GENE_INFO','TYPE','TYPE_DESCRIPTION']

print("-"*100)
print(pathway.head())
print("-"*100)
print(gene_pathway.head())
print("-"*100)
print(gene_info.head())
print("-"*100)
# Out:
# Fetching data from https://rest.kegg.jp/list/pathway/hsa...
# Fetching data from https://rest.kegg.jp/link/pathway/hsa...
# Fetching data from https://rest.kegg.jp/list/hsa...
# ----------------------------------------------------------------------------------------------------
#   PATHWAY_ID                                       PATHWAY_NAME
# 0   hsa01100          Metabolic pathways - Homo sapiens (human)
# 1   hsa01200           Carbon metabolism - Homo sapiens (human)
# 2   hsa01210  2-Oxocarboxylic acid metabolism - Homo sapiens...
# 3   hsa01212       Fatty acid metabolism - Homo sapiens (human)
# 4   hsa01230  Biosynthesis of amino acids - Homo sapiens (hu...
# ----------------------------------------------------------------------------------------------------
#      GENE_ID PATHWAY_ID
# 0  hsa:10327   hsa00010
# 1    hsa:124   hsa00010
# 2    hsa:125   hsa00010
# 3    hsa:126   hsa00010
# 4    hsa:127   hsa00010
# ----------------------------------------------------------------------------------------------------
#          GENE_ID GENE_INFO                          TYPE  \
# 0  hsa:102466751     miRNA    1:complement(17369..17436)
# 1  hsa:100302278     miRNA                1:30366..30503
# 2      hsa:79501       CDS                1:65419..71585
# 3  hsa:102465909     miRNA  1:complement(187891..187958)
# 4  hsa:112268260       CDS  1:complement(365134..382235)
#
#                                     TYPE_DESCRIPTION
# 0         MIR6859-1, hsa-mir-6859-1; microRNA 6859-1
# 1  MIR1302-2, MIRN1302-2, hsa-mir-1302-2; microRN...
# 2  OR4F5; olfactory receptor family 4 subfamily F...
# 3         MIR6859-2, hsa-mir-6859-2; microRNA 6859-2
# 4                       uncharacterized LOC112268260
# ----------------------------------------------------------------------------------------------------

# %%
# ==========================================
#  Data Cleaning and Parsing
# ==========================================
print("Parsing gene information...")

# The gene list from KEGG comes as "Symbol; Description" in one column. 
# We need to split it.

def extract_gene_symbol(row):
    """
    Extracts gene symbol and gene name from KEGG TYPE_DESCRIPTION.
    
    TYPE_DESCRIPTION format:
    SYMBOL1, SYMBOL2, ... ; Full gene name
    """
    desc = row["TYPE_DESCRIPTION"]

    if pd.isna(desc):
        return pd.Series(["NA", "NA"])

    # Split symbol(s) and description
    if ";" in desc:
        symbol_part, gene_name = desc.split(";", 1)
    else:
        symbol_part = desc
        gene_name = "NA"

    # First symbol is the primary gene symbol
    gene_symbol = symbol_part.split(",")[0].strip()

    return pd.Series([gene_symbol, gene_name.strip()])

gene_info[["GENE_SYMBOL", "GENE_NAME"]] = gene_info.apply(
    extract_gene_symbol, axis=1
)

genes = gene_info[
    ["GENE_ID", "GENE_SYMBOL", "GENE_NAME", "TYPE"]
]

print(genes.head())
print("Unique gene symbols:", genes["GENE_SYMBOL"].nunique())

# Drop rows where gene symbol could not be extracted
genes = genes.dropna(subset=["GENE_SYMBOL"])

# Very rare edge cases
genes = genes[~genes["GENE_SYMBOL"].isin(["-", "NA"])]

print("After cleaning:", genes.shape)
# Out:
# Parsing gene information...
#          GENE_ID                   GENE_SYMBOL  \
# 0  hsa:102466751                     MIR6859-1
# 1  hsa:100302278                     MIR1302-2
# 2      hsa:79501                         OR4F5
# 3  hsa:102465909                     MIR6859-2
# 4  hsa:112268260  uncharacterized LOC112268260
#
#                                           GENE_NAME  \
# 0                                   microRNA 6859-1
# 1                                   microRNA 1302-2
# 2  olfactory receptor family 4 subfamily F member 5
# 3                                   microRNA 6859-2
# 4                                                NA
#
#                            TYPE
# 0    1:complement(17369..17436)
# 1                1:30366..30503
# 2                1:65419..71585
# 3  1:complement(187891..187958)
# 4  1:complement(365134..382235)
# Unique gene symbols: 22958
# After cleaning: (24684, 4)

# %%
##==========================================
##  Merging all data
##==========================================
print("Merging datasets...")

# Merge all data into one master table
merged = (
    gene_pathway
    .merge(pathways, on="PATHWAY_ID", how="left")
    .merge(genes, on="GENE_ID", how="inner")
)

print(merged.head())
# Out:
# Merging datasets...
#      GENE_ID PATHWAY_ID                                       PATHWAY_NAME  \
# 0  hsa:10327   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
# 1    hsa:124   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
# 2    hsa:125   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
# 3    hsa:126   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
# 4    hsa:127   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
#
#   GENE_SYMBOL                                          GENE_NAME  \
# 0      AKR1A1             aldo-keto reductase family 1 member A1
# 1       ADH1A  alcohol dehydrogenase 1A (class I), alpha poly...
# 2       ADH1B  alcohol dehydrogenase 1B (class I), beta polyp...
# 3       ADH1C  alcohol dehydrogenase 1C (class I), gamma poly...
# 4        ADH4  alcohol dehydrogenase 4 (class II), pi polypep...
#
#                                TYPE
# 0              1:45550826..45570049
# 1  4:complement(99276369..99290985)
# 2  4:complement(99304971..99321401)
# 3  4:complement(99336497..99352746)
# 4  4:complement(99123658..99144297)

# %%
##==========================================
##  Computing pathway and Gene Set
##==========================================

pathway_genes = (
    merged
    .groupby(["PATHWAY_ID", "PATHWAY_NAME"])["GENE_SYMBOL"]
    .apply(set)
    .reset_index()
)

print(pathway_genes.head())
# Out:
#   PATHWAY_ID                                       PATHWAY_NAME  \
# 0   hsa00010  Glycolysis / Gluconeogenesis - Homo sapiens (h...
# 1   hsa00020   Citrate cycle (TCA cycle) - Homo sapiens (human)
# 2   hsa00030   Pentose phosphate pathway - Homo sapiens (human)
# 3   hsa00040  Pentose and glucuronate interconversions - Hom...
# 4   hsa00051  Fructose and mannose metabolism - Homo sapiens...
#
#                                          GENE_SYMBOL
# 0  {PGAM2, ENO4, ADH5, HKDC1, ALDH9A1, PCK1, ACSS...
# 1  {IDH3B, SDHA, SUCLG2, FH, PCK1, OGDH, PDHA1, M...
# 2  {PRPS1L1, GLYCTK, PFKM, RPEL1, FBP1, TKTL1, FB...
# 3  {UGT2A2, DCXR, UGT2B28, UGT2B7, RPEL1, UGT2A1,...
# 4  {PMM2, PFKFB2, HKDC1, PFKFB1, KHK, GMPPA, PFKM...

# %%
##==========================================
##  Computing crosstalk analysis 
##==========================================

crosstalk_results = []

# Compare every pair
for(path_id_1, path_name_1, genes1), (path_id_2, path_name_2, genes2) in combinations(pathway_genes.values, 2):
    overlap = genes1 & genes2
    if overlap:
        crosstalk_results.append({
            'PATHWAY_ID1': path_id_1,
            'PATHWAY_NAME1': path_name_1,
            'PATHWAY_ID2': path_id_2,
            'PATHWAY_NAME2': path_name_2,
            'NUMBER_OF_OVERLAPPING_GENES': len(overlap),
            'LIST_OF_OVERLAPPING_GENES': ";".join(sorted(overlap))
        })

## Save Results
crosstalk_df = pd.DataFrame(crosstalk_results)
crosstalk_df = crosstalk_df.sort_values(
    "NUMBER_OF_OVERLAPPING_GENES", ascending=False
)
crosstalk_df.to_csv("KEGG_crosstalk.csv", index=False)
print("Saved KEGG_crosstalk.csv")
# Out:
# Saved KEGG_crosstalk.csv

# %%
##==========================================
## Gene Centrality Analysis
##==========================================
# Count number of pathways per gene
gene_rank = (
    merged.groupby("GENE_SYMBOL")["PATHWAY_ID"]
    .nunique()
    .sort_values(ascending=False)
    .reset_index(name="NUM_PATHWAYS")
)
gene_rank.to_csv("gene_pathway_rank.csv", index=False)
print("Saved gene_pathway_rank.csv")
# Out:
# Saved gene_pathway_rank.csv

# %%
##==========================================
## Shared Pathways for Top genes
##==========================================
top_genes = gene_rank["GENE_SYMBOL"].head(4).tolist()

# Retrieve sets of pathways for these genes
gene_to_pathways = (
    merged.groupby("GENE_SYMBOL")["PATHWAY_ID"]
    .apply(set)
)

# Find intersection
common = set.intersection(*[gene_to_pathways[g] for g in top_genes])
if not common:
    top_genes = top_genes[:3]
    common = set.intersection(*[gene_to_pathways[g] for g in top_genes])

print("Top genes:", top_genes)
#print("Common pathways:", common)
# Out:
# Top genes: ['MAPK3', 'MAPK1', 'PIK3CA', 'PIK3CD']

# %%
##==========================================
## Venn Diagram
##==========================================

venn_data = {g: gene_to_pathways[g] for g in top_genes}
venn(venn_data)
plt.title("Pathway overlap among top genes")
plt.show()

# %% [markdown]
# ## New Feature added -> JACCARD INDEX
#
# Some KEGG pathways are very large and naturally overlap with many other pathways simply because they contain many genes. However, not all overlaps are biologically meaningful, some may just be due to pathway size.
#
# To address this, we compute the Jaccard similarity between pathways. The Jaccard index measures the proportion of shared genes relative to the total number of unique genes in the two pathways, effectively normalizing overlap by pathway size.
#
# This helps interpret pathway overlaps biologically:
#
# 1. High overlap + High Jaccard: Likely true functional coupling between the pathways.
# 2. High overlap + Low Jaccard: Overlap is mostly driven by pathway size, may not be biologically meaningful.
# 3. Low overlap + High Jaccard: Small pathways, but the shared genes suggest a tight functional connection.
#
# In short, the Jaccard index helps us distinguish meaningful biological overlaps from size-driven artifacts.

# %%
##==========================================
## Jaccard-normalized pathway crosstalk
##==========================================

jaccard_results = []
for (path_id_1, path_name_1, genes1), (path_id_2, path_name_2, genes2) in combinations(pathway_genes.values, 2):
    intersection = genes1 & genes2
    union = genes1 | genes2

    if intersection:
        jaccard_results.append({
            "PATHWAY_ID1": path_id_1,
            "PATHWAY_NAME1": path_name_1,
            "PATHWAY_ID2": path_id_2,
            "PATHWAY_NAME2": path_name_2,
            "NUM_OVERLAPPING_GENES": len(intersection),
            "JACCARD_SCORE": len(intersection) / len(union),
            "OVERLAPPING_GENES": ";".join(sorted(intersection))
        })

## Creating the results table
jaccard_df = (
    pd.DataFrame(jaccard_results)
    .sort_values(
        by=["JACCARD_SCORE", "NUM_OVERLAPPING_GENES"],
        ascending=[False, False]
    )
)

print(jaccard_df.head(5))
# Out:
#       PATHWAY_ID1                                      PATHWAY_NAME1  \
# 23071    hsa05410  Hypertrophic cardiomyopathy - Homo sapiens (hu...
# 1946     hsa00980  Metabolism of xenobiotics by cytochrome P450 -...
# 1210     hsa00520  Amino sugar and nucleotide sugar metabolism - ...
# 19722    hsa04940    Type I diabetes mellitus - Homo sapiens (human)
# 1586     hsa00591    Linoleic acid metabolism - Homo sapiens (human)
#
#       PATHWAY_ID2                                      PATHWAY_NAME2  \
# 23071    hsa05414      Dilated cardiomyopathy - Homo sapiens (human)
# 1946     hsa00982  Drug metabolism - cytochrome P450 - Homo sapie...
# 1210     hsa01250  Biosynthesis of nucleotide sugars - Homo sapie...
# 19722    hsa05330         Allograft rejection - Homo sapiens (human)
# 1586     hsa00592  alpha-Linolenic acid metabolism - Homo sapiens...
#
#        NUM_OVERLAPPING_GENES  JACCARD_SCORE  \
# 23071                     89       0.773913
# 1946                      62       0.704545
# 1210                      30       0.666667
# 19722                     33       0.660000
# 1586                      22       0.647059
#
#                                        OVERLAPPING_GENES
# 23071  ACTB;ACTC1;ACTG1;AGT;ATP2A1;ATP2A2;ATP2A3;CACN...
# 1946   ADH1A;ADH1B;ADH1C;ADH4;ADH5;ADH6;ADH7;ALDH3A1;...
# 1210   FCSK;FPGT;GALE;GALK1;GALK2;GALT;GCK;GFPT1;GFPT...
# 19722  CD28;CD80;CD86;FAS;FASLG;GZMB;HLA-A;HLA-B;HLA-...
# 1586   JMJD7-PLA2G4B;PLA2G10;PLA2G12A;PLA2G12B;PLA2G1...

# %% [markdown]
# ### Result table interpretation
#
# ##### In the table we see the top pathways which are fucntionally similar. Each row shows 2 pathways that share the largest proportion of genes.
# ##### For eg: Hypertophic Cardiomypathy and Dialated Cardiomypathy are clinically related diseases,
# ##### So we see a strong overlap which is expected biologically.
# ##### The table also shows numebr of overlapping genes .i.e. 89 genes in this case.
# ##### The jaccard score 0.774 shows that 77% of all genes in these pathways are same further inferring that there is tight functional coupling between the pathways

# %%
##==============================================
## Visualizing through a netwrok lens
##==============================================
## Nodes -> KEGG pathways
## Edges-> Strong crosstalk/ High Jaccard Similarity)
## Dense Clusters(Hubs) -> Pathways involved in the same biological process


import networkx as nx
import matplotlib.pyplot as plt

## Filter pathway pairs by Jaccard threshold
## Keeps only strong, biologically meaningful connections
JACCARD_THRESHOLD = 0.5

network_df = jaccard_df[
    jaccard_df["JACCARD_SCORE"] >= JACCARD_THRESHOLD
]

## Build pathway crosstalk network
G = nx.Graph()

# Add edges
for _, row in network_df.iterrows():
    G.add_edge(
        row["PATHWAY_NAME1"],
        row["PATHWAY_NAME2"],
        weight=row["JACCARD_SCORE"]
    )

## Visualize the network

plt.figure(figsize=(12, 12))

# Layout: spring layout for biological networks
pos = nx.spring_layout(G, seed=42, k=0.4)

# Node sizes proportional to degree to make sure hub pathways stand out
node_sizes = [G.degree(n) * 300 for n in G.nodes()]

# Edge widths proportional to Jaccard similarity
edge_widths = [G[u][v]["weight"] * 4 for u, v in G.edges()]

# Draw nodes
nx.draw_networkx_nodes(G,pos,node_size=node_sizes,alpha=0.85)

# Draw edges
nx.draw_networkx_edges(G,pos,width=edge_widths,alpha=0.6)

# Draw labels
nx.draw_networkx_labels(G,pos,font_size=8)

plt.title(
    "KEGG Pathway Crosstalk Network\n"
    f"(Edges: Jaccard ≥ {JACCARD_THRESHOLD})"
)
plt.axis("off")
plt.show()
